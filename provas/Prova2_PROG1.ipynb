# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exercicios/blob/main/provas/Prova2_PROG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Faça um programa em Python 3 que pergunte quanto um usuario
recebe por hora e o número de horas trabalhadas no mês.
Calcule e mostre o total do salário no referido mês,
sabendo-se que são descontados 11% para o imposto de renda,
8% para o INSS e 5% para o sindicato, o algoritimo deverá
exibir: o salário bruto, quanto foi pago para o INSS, quanto
foi pago ao sindicato e o salário liquido. Calcule os
descontos e o salário líquido, conforme tabela abaixo:
+ Salário Bruto : R$
- IR (11%) : R$
- INSS (8%) : R$
- Sindicato (5%) : R$
= Salário Líquido : R$
ENTRADA
Haverá duas linhas na entrada. A primeira deverá receber o valor
da sua hora trabalhada, a qual terá a seguinte menssagem
"Digite o valor da hora trabalhada:". A segunda linha receberá a
quantidade de horas trabalhadas no mês, a qual terá a seguinte
menssagem para a entrada de dados "Digite a quantidade de horas
trabalhadas:". Observe que ambas as entradas devem conter a
menssagem correta solicitando as informções ao usuario
conforme exemplo abaixo.
SAIDA
A saida deverá conter as menssagens conforme o exemplo abaixo,
exibindo o salário bruto, o valor do imposto de renda, INSS,
Sindicato e, por fim, o salário líquido. Observe que as menssagens
devem ser exibidas conforme exemplo abaixo.
'''
#Entradas
valor_hora = float(input('Digite o valor da hora trabalhada: '))
horas_trabalhadas = int(input('Digite a quantidade de horas trabalhadas: '))
#Processamento
salario_bruto = valor_hora * horas_trabalhadas
ir = salario_bruto * .11
inss = salario_bruto * .08
sindicato = salario_bruto * .05
salario_liquido = salario_bruto - ir - inss - sindicato
#Saida
print(f'+ Salário Bruto : R$ {salario_bruto:.2f}')
print(f'- IR (11%) : R$ {ir:.2f}')
print(f'- INSS (8%) : R$ {inss:.2f}')
print(f'- Sindicato (5%) : R$ {sindicato:.2f}')
print(f'= Salário Líquido : R$ {salario_liquido:.2f}')
# Out:
# Digite o valor da hora trabalhada: 40
# Digite a quantidade de horas trabalhadas: 100
# + Salário Bruto : R$ 4000.00
# - IR (11%) : R$ 440.00
# - INSS (8%) : R$ 320.00
# - Sindicato (5%) : R$ 200.00
# = Salário Líquido : R$ 3040.00

# %% [markdown]
# ![WhatsApp Image 2026-07-27 at 22.25.49.jpeg](data:image/jpeg;base64,...)
