# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exercicios/blob/main/Conceitos-basicos/permissoes_no_linux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![aaaaaaaaa.png](data:image/png;base64,...)

# %%
#Entradas
permissao = (input())

#Processamento
owner_read = str(permissao[0]) == '7' or str(permissao[0]) == '6' or str(permissao[0]) == '5' or str(permissao[0]) == '4'
owner_write = str(permissao[0]) == '7' or str(permissao[0]) == '6' or str(permissao[0]) == '3' or str(permissao[0]) == '2'
owner_exec = str(permissao[0]) == '7' or str(permissao[0]) == '5' or str(permissao[0]) == '3' or str(permissao[0]) == '1'

group_read = str(permissao[1]) == '7' or str(permissao[1]) == '6' or str(permissao[1]) == '5' or str(permissao[1]) == '4'
group_write = str(permissao[1]) == '7' or str(permissao[1]) == '6'or str(permissao[1]) == '3' or str(permissao[1]) == '2'
group_exec = str(permissao[1]) == '7' or str(permissao[1]) == '5' or str(permissao[1]) == '3' or str(permissao[1]) == '1'

other_read = str(permissao[2]) == '7' or str(permissao[2]) == '6' or str(permissao[2]) == '5' or str(permissao[2]) == '4'
other_write = str(permissao[2]) == '7' or str(permissao[2]) == '6' or str(permissao[2]) == '3'or str(permissao[2]) == '2'
other_exec = str(permissao[2]) == '7' or str(permissao[2]) == '5' or str(permissao[2]) == '3' or str(permissao[2]) == '1'

owner_all = str(permissao[0]) == '7'
world_read = owner_read and group_read and other_read
no_world_write = owner_write and group_write and other_write

#Saidas:
print('OWNER_READ:', owner_read)
print('OWNER_WRITE:', owner_write)
print('OWNER_EXEC: ', owner_exec)
print('GROUP_READ:', group_read)
print('GROUP_WRITE:', group_write)
print('GROUP_EXEC:', group_exec)
print('OTHER_READ:', other_read)
print('OTHER_WRITE:', other_write)
print('OTHER_EXEC:', other_exec)
print('OWNER_ALL:', owner_all)
print('WORLD_READ:', world_read)
print('NO_WORLD_WRITE:', not no_world_write)
# Out:
# 644
# OWNER_READ: True
# OWNER_WRITE: True
# OWNER_EXEC:  False
# GROUP_READ: True
# GROUP_WRITE: False
# GROUP_EXEC: False
# OTHER_READ: True
# OTHER_WRITE: False
# OTHER_EXEC: False
# OWNER_ALL: False
# WORLD_READ: True
# NO_WORLD_WRITE: True
