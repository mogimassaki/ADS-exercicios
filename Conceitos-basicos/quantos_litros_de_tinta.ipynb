# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exercicios/blob/main/Conceitos-basicos/quantos_litros_de_tinta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
largura = float(input())
altura = float(input())
valor_litro = float(input())
area = largura * altura
litros_gastos = area / 1.75
custo = litros_gastos * valor_litro
print(f'{custo:.2f}')
# Out:
# 4.50
# 3.50
# 32.00
# 288.0

# %% [markdown]
# ![aaaaaaaaa.png](data:image/png;base64,...)
